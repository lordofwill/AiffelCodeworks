# %% [markdown]
# ### 패키지 import
# ---
# 필요 library 들여오기

# %%
import os, re
import random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### 데이터 가져오기 및  초반 세팅
# ---
# 데이터를 불러오고 batchsize와 epoch을 정합니다.

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*' # *은 모든 디렉토리와 파일을 의미합니다.
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

# 프로젝트를 진행할 때 아래 두 변수를 변경해보세요
BATCH_SIZE = 16
EPOCHS = 25

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %% [markdown]
# ### 전처리
# ---
# 데이터를 학습용과 검증용 및 최종 확인용으로 나누고, 레이블을 붙입니다.\
# 그 외에 사이즈 수정등의 처리도 진행합니다.

# %%
# train 데이터와 validation 데이터를 모두 filenames에 담습니다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %%
print(f'Normal image path\n{filenames[0]}')
print(f'Pneumonia image path\n{filenames[2000]}')
# Out:
# Normal image path
# /aiffel/aiffel/chest_xray/data/train/NORMAL/NORMAL2-IM-0618-0001.jpeg
# Pneumonia image path
# /aiffel/aiffel/chest_xray/data/train/PNEUMONIA/person399_virus_793.jpeg

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")


COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1070
# Pneumonia images count in training set: 3115

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %%
# 이미지를 알맞은 형식으로 바꿉니다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %%
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %% [markdown]
# ### 전처리2
# ---
# augmentation을 진행하는데, 비교 할 모델을 위해 augmentation이 사용되지 않는 경우도 만듭니다.

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds_noaug = prepare_for_training(train_ds)
val_ds_noaug = prepare_for_training(val_ds)

# %%
def augment(image,label):
    image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전합니다.
    return image,label

def prepare_for_training(ds, shuffle_buffer_size=1000):
    # augment 적용 부분이 배치처리 함수에 추가되었습니다.
    ds = ds.map(
            augment,       # augment 함수 적용
            num_parallel_calls=2
        )
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# ### 시각화
# ---
# augmentation을 적용한 것과 적용하지 않은 것을 각각 시각화해봤습니다.\
# 처음이 augmentation이 적용된 것이고, 뒤의 것이 적용되지 않은 것입니다.

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(5,math.ceil(BATCH_SIZE/5),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %%
image_batch_noaug, label_batch_noaug = next(iter(train_ds_noaug))
show_batch(image_batch_noaug.numpy(), label_batch_noaug.numpy())

# %% [markdown]
# ### 모델 생성
# ---
# 모델을 생성하는데 dropout을 적용한 것과 적용하지 않은 것을 생성했습니다.\
# 처음 것이 dropout이 적용된 모델이고, 나중 것이 dropout이 적용되지 않은 모델입니다.

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# dropout이 적용되지 않은 모델

# %%
def dense_block_nodrop(units):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
#         tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model_nodrop():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
#         tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
#         tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block_nodrop(512),
        dense_block_nodrop(128),
        dense_block_nodrop(64),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# 데이터의 불균형을 해소하기위한 가중치 설정부분입니다.

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.96
# Weight for PNEUMONIA: 0.67

# %% [markdown]
# ### 모델 훈련
# ---
# augmentation을 적용하고 dropout을 적용하지 않은 모델이 첫 번째,\
# augmentation을 적용하지 않고 dropout이 적용된 모델이 두 번째,\
# augmentation과 dropout을 모두 적용한 모델이 세 번째입니다.

# %%
with tf.device('/GPU:0'):
    model_nodrop_aug = build_model_nodrop()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model_nodrop_aug.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history_nodrop_aug = model_nodrop_aug.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // (BATCH_SIZE),
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // (BATCH_SIZE),
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 73s 236ms/step - loss: 0.3086 - accuracy: 0.8645 - precision: 0.9654 - recall: 0.8472 - val_loss: 0.6738 - val_accuracy: 0.7356 - val_precision: 0.7356 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 60s 231ms/step - loss: 0.1706 - accuracy: 0.9357 - precision: 0.9799 - recall: 0.9332 - val_loss: 0.9783 - val_accuracy: 0.7327 - val_precision: 0.7327 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 60s 230ms/step - loss: 0.1546 - accuracy: 0.9448 - precision: 0.9807 - recall: 0.9449 - val_loss: 0.1098 - val_accuracy: 0.9731 - val_precision: 0.9717 - val_recall: 0.9921
# Epoch 4/25
# 261/261 [==============================] - 60s 231ms/step - loss: 0.1182 - accuracy: 0.9555 - precision: 0.9893 - recall: 0.9507 - val_loss: 0.9698 - val_accuracy: 0.7337 - val_precision: 0.7334 - val_recall: 1.0000
# Epoch 5/25
# 261/261 [==============================] - 62s 237ms/step - loss: 0.1055 - accuracy: 0.9608 - precision: 0.9880 - recall: 0.9590 - val_loss: 0.2433 - val_accuracy: 0.9183 - val_precision: 0.9956 - val_recall: 0.8927
# Epoch 6/25
# 261/261 [==============================] - 65s 248ms/step - loss: 0.1070 - accuracy: 0.9588 - precision: 0.9910 - recall: 0.9535 - val_loss: 0.0888 - val_accuracy: 0.9712 - val_precision: 0.9893 - val_recall: 0.9712
# Epoch 7/25
# 261/261 [==============================] - 67s 257ms/step - loss: 0.1178 - accuracy: 0.9551 - precision: 0.9884 - recall: 0.9499 - val_loss: 0.1991 - val_accuracy: 0.9173 - val_precision: 0.9899 - val_recall: 0.8965
# Epoch 8/25
# 261/261 [==============================] - 59s 225ms/step - loss: 0.1083 - accuracy: 0.9563 - precision: 0.9870 - recall: 0.9543 - val_loss: 0.0834 - val_accuracy: 0.9654 - val_precision: 0.9853 - val_recall: 0.9672
# Epoch 9/25
# 261/261 [==============================] - 58s 223ms/step - loss: 0.0898 - accuracy: 0.9634 - precision: 0.9897 - recall: 0.9609 - val_loss: 0.1325 - val_accuracy: 0.9577 - val_precision: 0.9959 - val_recall: 0.9462
# Epoch 10/25
# 261/261 [==============================] - 58s 223ms/step - loss: 0.0639 - accuracy: 0.9742 - precision: 0.9933 - recall: 0.9720 - val_loss: 0.0690 - val_accuracy: 0.9760 - val_precision: 0.9719 - val_recall: 0.9961
# Epoch 11/25
# 261/261 [==============================] - 58s 221ms/step - loss: 0.0966 - accuracy: 0.9615 - precision: 0.9891 - recall: 0.9586 - val_loss: 0.1822 - val_accuracy: 0.9481 - val_precision: 0.9415 - val_recall: 0.9908
# Epoch 12/25
# 261/261 [==============================] - 58s 221ms/step - loss: 0.1039 - accuracy: 0.9588 - precision: 0.9869 - recall: 0.9585 - val_loss: 0.1533 - val_accuracy: 0.9462 - val_precision: 0.9986 - val_recall: 0.9279
# Epoch 13/25
# 261/261 [==============================] - 58s 224ms/step - loss: 0.0871 - accuracy: 0.9684 - precision: 0.9911 - recall: 0.9658 - val_loss: 0.1725 - val_accuracy: 0.9346 - val_precision: 0.9182 - val_recall: 1.0000
# Epoch 14/25
# 261/261 [==============================] - 58s 223ms/step - loss: 0.0552 - accuracy: 0.9765 - precision: 0.9953 - recall: 0.9731 - val_loss: 0.0587 - val_accuracy: 0.9740 - val_precision: 0.9718 - val_recall: 0.9934
# Epoch 15/25
# 261/261 [==============================] - 59s 227ms/step - loss: 0.0655 - accuracy: 0.9740 - precision: 0.9937 - recall: 0.9709 - val_loss: 0.2266 - val_accuracy: 0.9212 - val_precision: 1.0000 - val_recall: 0.8924
# Epoch 16/25
# 261/261 [==============================] - 59s 227ms/step - loss: 0.0654 - accuracy: 0.9739 - precision: 0.9947 - recall: 0.9713 - val_loss: 0.0787 - val_accuracy: 0.9731 - val_precision: 0.9693 - val_recall: 0.9948
# Epoch 17/25
# 261/261 [==============================] - 59s 226ms/step - loss: 0.0565 - accuracy: 0.9777 - precision: 0.9945 - recall: 0.9757 - val_loss: 0.2689 - val_accuracy: 0.9029 - val_precision: 1.0000 - val_recall: 0.8675
# Epoch 18/25
# 261/261 [==============================] - 59s 227ms/step - loss: 0.0543 - accuracy: 0.9788 - precision: 0.9973 - recall: 0.9746 - val_loss: 0.1572 - val_accuracy: 0.9442 - val_precision: 1.0000 - val_recall: 0.9240
# Epoch 19/25
# 261/261 [==============================] - 58s 224ms/step - loss: 0.0533 - accuracy: 0.9798 - precision: 0.9946 - recall: 0.9781 - val_loss: 0.0605 - val_accuracy: 0.9798 - val_precision: 0.9806 - val_recall: 0.9921
# Epoch 20/25
# 261/261 [==============================] - 59s 227ms/step - loss: 0.0586 - accuracy: 0.9793 - precision: 0.9936 - recall: 0.9785 - val_loss: 0.0560 - val_accuracy: 0.9817 - val_precision: 0.9921 - val_recall: 0.9830
# Epoch 21/25
# 261/261 [==============================] - 59s 227ms/step - loss: 0.0471 - accuracy: 0.9842 - precision: 0.9954 - recall: 0.9836 - val_loss: 0.0686 - val_accuracy: 0.9740 - val_precision: 0.9742 - val_recall: 0.9908
# Epoch 22/25
# 261/261 [==============================] - 61s 234ms/step - loss: 0.0436 - accuracy: 0.9846 - precision: 0.9966 - recall: 0.9826 - val_loss: 0.0500 - val_accuracy: 0.9817 - val_precision: 0.9947 - val_recall: 0.9804
# Epoch 23/25
# 261/261 [==============================] - 59s 225ms/step - loss: 0.0429 - accuracy: 0.9824 - precision: 0.9957 - recall: 0.9805 - val_loss: 0.0757 - val_accuracy: 0.9673 - val_precision: 0.9946 - val_recall: 0.9607
# Epoch 24/25
# 261/261 [==============================] - 58s 224ms/step - loss: 0.0345 - accuracy: 0.9867 - precision: 0.9980 - recall: 0.9844 - val_loss: 0.1872 - val_accuracy: 0.9356 - val_precision: 0.9986 - val_recall: 0.9134
# Epoch 25/25
# 261/261 [==============================] - 59s 225ms/step - loss: 0.0407 - accuracy: 0.9865 - precision: 0.9982 - recall: 0.9835 - val_loss: 0.0955 - val_accuracy: 0.9654 - val_precision: 0.9946 - val_recall: 0.9581

# %% [markdown]
# 두 번째

# %%
with tf.device('/GPU:0'):
    model_noaug = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model_noaug.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history_noaug = model_noaug.fit(
        train_ds_noaug,
        steps_per_epoch=TRAIN_IMG_COUNT // (BATCH_SIZE),
        epochs=EPOCHS,
        validation_data=val_ds_noaug,
        validation_steps=VAL_IMG_COUNT // (BATCH_SIZE),
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 73s 237ms/step - loss: 0.5257 - accuracy: 0.7368 - precision: 0.9242 - recall: 0.7067 - val_loss: 0.6423 - val_accuracy: 0.7346 - val_precision: 0.7346 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 60s 232ms/step - loss: 0.2225 - accuracy: 0.9075 - precision: 0.9776 - recall: 0.8956 - val_loss: 1.0565 - val_accuracy: 0.7356 - val_precision: 0.7356 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 60s 232ms/step - loss: 0.2100 - accuracy: 0.9270 - precision: 0.9801 - recall: 0.9214 - val_loss: 0.4075 - val_accuracy: 0.7490 - val_precision: 0.7451 - val_recall: 1.0000
# Epoch 4/25
# 261/261 [==============================] - 61s 233ms/step - loss: 0.1675 - accuracy: 0.9385 - precision: 0.9836 - recall: 0.9323 - val_loss: 0.0841 - val_accuracy: 0.9721 - val_precision: 0.9986 - val_recall: 0.9634
# Epoch 5/25
# 261/261 [==============================] - 63s 243ms/step - loss: 0.1501 - accuracy: 0.9453 - precision: 0.9860 - recall: 0.9402 - val_loss: 0.1900 - val_accuracy: 0.9231 - val_precision: 1.0000 - val_recall: 0.8950
# Epoch 6/25
# 261/261 [==============================] - 64s 245ms/step - loss: 0.1453 - accuracy: 0.9444 - precision: 0.9860 - recall: 0.9393 - val_loss: 0.1468 - val_accuracy: 0.9394 - val_precision: 0.9957 - val_recall: 0.9213
# Epoch 7/25
# 261/261 [==============================] - 68s 261ms/step - loss: 0.1337 - accuracy: 0.9463 - precision: 0.9923 - recall: 0.9368 - val_loss: 0.3538 - val_accuracy: 0.8490 - val_precision: 1.0000 - val_recall: 0.7948
# Epoch 8/25
# 261/261 [==============================] - 59s 226ms/step - loss: 0.1293 - accuracy: 0.9510 - precision: 0.9873 - recall: 0.9464 - val_loss: 0.2366 - val_accuracy: 0.9000 - val_precision: 1.0000 - val_recall: 0.8637
# Epoch 9/25
# 261/261 [==============================] - 58s 224ms/step - loss: 0.1518 - accuracy: 0.9462 - precision: 0.9868 - recall: 0.9399 - val_loss: 0.0791 - val_accuracy: 0.9673 - val_precision: 1.0000 - val_recall: 0.9554
# Epoch 10/25
# 261/261 [==============================] - 59s 228ms/step - loss: 0.1399 - accuracy: 0.9472 - precision: 0.9872 - recall: 0.9419 - val_loss: 0.1047 - val_accuracy: 0.9596 - val_precision: 0.9986 - val_recall: 0.9462
# Epoch 11/25
# 261/261 [==============================] - 58s 224ms/step - loss: 0.1136 - accuracy: 0.9602 - precision: 0.9891 - recall: 0.9573 - val_loss: 0.0642 - val_accuracy: 0.9702 - val_precision: 0.9933 - val_recall: 0.9660
# Epoch 12/25
# 261/261 [==============================] - 60s 230ms/step - loss: 0.0963 - accuracy: 0.9670 - precision: 0.9928 - recall: 0.9624 - val_loss: 0.1169 - val_accuracy: 0.9471 - val_precision: 0.9986 - val_recall: 0.9293
# Epoch 13/25
# 261/261 [==============================] - 59s 225ms/step - loss: 0.1027 - accuracy: 0.9620 - precision: 0.9900 - recall: 0.9579 - val_loss: 0.0949 - val_accuracy: 0.9606 - val_precision: 1.0000 - val_recall: 0.9462
# Epoch 14/25
# 261/261 [==============================] - 58s 224ms/step - loss: 0.0986 - accuracy: 0.9630 - precision: 0.9910 - recall: 0.9589 - val_loss: 0.0486 - val_accuracy: 0.9779 - val_precision: 0.9973 - val_recall: 0.9724
# Epoch 15/25
# 261/261 [==============================] - 58s 222ms/step - loss: 0.0824 - accuracy: 0.9731 - precision: 0.9943 - recall: 0.9692 - val_loss: 0.2162 - val_accuracy: 0.9260 - val_precision: 0.9971 - val_recall: 0.9014
# Epoch 16/25
# 261/261 [==============================] - 58s 224ms/step - loss: 0.0963 - accuracy: 0.9637 - precision: 0.9892 - recall: 0.9621 - val_loss: 1.3262 - val_accuracy: 0.7433 - val_precision: 0.7408 - val_recall: 1.0000
# Epoch 17/25
# 261/261 [==============================] - 57s 220ms/step - loss: 0.1228 - accuracy: 0.9559 - precision: 0.9867 - recall: 0.9537 - val_loss: 0.0457 - val_accuracy: 0.9808 - val_precision: 0.9960 - val_recall: 0.9777
# Epoch 18/25
# 261/261 [==============================] - 58s 223ms/step - loss: 0.0726 - accuracy: 0.9739 - precision: 0.9925 - recall: 0.9725 - val_loss: 0.0620 - val_accuracy: 0.9788 - val_precision: 0.9831 - val_recall: 0.9882
# Epoch 19/25
# 261/261 [==============================] - 60s 229ms/step - loss: 0.0978 - accuracy: 0.9659 - precision: 0.9899 - recall: 0.9642 - val_loss: 0.0607 - val_accuracy: 0.9788 - val_precision: 0.9805 - val_recall: 0.9908
# Epoch 20/25
# 261/261 [==============================] - 58s 223ms/step - loss: 0.0692 - accuracy: 0.9753 - precision: 0.9952 - recall: 0.9718 - val_loss: 0.1062 - val_accuracy: 0.9606 - val_precision: 0.9972 - val_recall: 0.9488
# Epoch 21/25
# 261/261 [==============================] - 58s 221ms/step - loss: 0.0751 - accuracy: 0.9714 - precision: 0.9942 - recall: 0.9677 - val_loss: 0.0504 - val_accuracy: 0.9817 - val_precision: 0.9843 - val_recall: 0.9908
# Epoch 22/25
# 261/261 [==============================] - 57s 221ms/step - loss: 0.0685 - accuracy: 0.9765 - precision: 0.9936 - recall: 0.9745 - val_loss: 0.1996 - val_accuracy: 0.9144 - val_precision: 1.0000 - val_recall: 0.8834
# Epoch 23/25
# 261/261 [==============================] - 58s 222ms/step - loss: 0.0554 - accuracy: 0.9772 - precision: 0.9967 - recall: 0.9727 - val_loss: 0.0463 - val_accuracy: 0.9769 - val_precision: 0.9920 - val_recall: 0.9764
# Epoch 24/25
# 261/261 [==============================] - 58s 223ms/step - loss: 0.0814 - accuracy: 0.9716 - precision: 0.9936 - recall: 0.9684 - val_loss: 0.1020 - val_accuracy: 0.9663 - val_precision: 0.9597 - val_recall: 0.9961
# Epoch 25/25
# 261/261 [==============================] - 58s 223ms/step - loss: 0.0751 - accuracy: 0.9704 - precision: 0.9914 - recall: 0.9693 - val_loss: 0.0460 - val_accuracy: 0.9837 - val_precision: 0.9908 - val_recall: 0.9869

# %% [markdown]
# 세 번째

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // (BATCH_SIZE),
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // (BATCH_SIZE),
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 73s 236ms/step - loss: 0.5512 - accuracy: 0.7090 - precision: 0.9184 - recall: 0.6613 - val_loss: 0.6362 - val_accuracy: 0.7337 - val_precision: 0.7337 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 63s 241ms/step - loss: 0.2675 - accuracy: 0.8785 - precision: 0.9661 - recall: 0.8679 - val_loss: 1.3639 - val_accuracy: 0.7327 - val_precision: 0.7327 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 63s 242ms/step - loss: 0.2294 - accuracy: 0.9098 - precision: 0.9765 - recall: 0.9019 - val_loss: 0.6576 - val_accuracy: 0.7510 - val_precision: 0.7468 - val_recall: 1.0000
# Epoch 4/25
# 261/261 [==============================] - 61s 235ms/step - loss: 0.1920 - accuracy: 0.9250 - precision: 0.9816 - recall: 0.9167 - val_loss: 0.1706 - val_accuracy: 0.9288 - val_precision: 0.9929 - val_recall: 0.9097
# Epoch 5/25
# 261/261 [==============================] - 62s 236ms/step - loss: 0.1756 - accuracy: 0.9292 - precision: 0.9823 - recall: 0.9209 - val_loss: 0.0930 - val_accuracy: 0.9692 - val_precision: 0.9704 - val_recall: 0.9882
# Epoch 6/25
# 261/261 [==============================] - 63s 242ms/step - loss: 0.1611 - accuracy: 0.9294 - precision: 0.9819 - recall: 0.9233 - val_loss: 0.1562 - val_accuracy: 0.9346 - val_precision: 0.9202 - val_recall: 0.9974
# Epoch 7/25
# 261/261 [==============================] - 68s 260ms/step - loss: 0.1689 - accuracy: 0.9372 - precision: 0.9806 - recall: 0.9331 - val_loss: 0.2703 - val_accuracy: 0.8904 - val_precision: 0.9969 - val_recall: 0.8534
# Epoch 8/25
# 261/261 [==============================] - 59s 226ms/step - loss: 0.1478 - accuracy: 0.9439 - precision: 0.9839 - recall: 0.9400 - val_loss: 0.1422 - val_accuracy: 0.9452 - val_precision: 0.9972 - val_recall: 0.9280
# Epoch 9/25
# 261/261 [==============================] - 60s 229ms/step - loss: 0.1328 - accuracy: 0.9415 - precision: 0.9856 - recall: 0.9353 - val_loss: 0.1842 - val_accuracy: 0.9115 - val_precision: 0.9970 - val_recall: 0.8822
# Epoch 10/25
# 261/261 [==============================] - 59s 228ms/step - loss: 0.1394 - accuracy: 0.9395 - precision: 0.9906 - recall: 0.9267 - val_loss: 0.4178 - val_accuracy: 0.8202 - val_precision: 0.9983 - val_recall: 0.7559
# Epoch 11/25
# 261/261 [==============================] - 59s 226ms/step - loss: 0.1906 - accuracy: 0.9308 - precision: 0.9779 - recall: 0.9281 - val_loss: 0.2362 - val_accuracy: 0.8885 - val_precision: 0.9985 - val_recall: 0.8491
# Epoch 12/25
# 261/261 [==============================] - 59s 225ms/step - loss: 0.1209 - accuracy: 0.9580 - precision: 0.9905 - recall: 0.9531 - val_loss: 0.3510 - val_accuracy: 0.8500 - val_precision: 0.9919 - val_recall: 0.8018
# Epoch 13/25
# 261/261 [==============================] - 60s 230ms/step - loss: 0.1391 - accuracy: 0.9440 - precision: 0.9902 - recall: 0.9362 - val_loss: 0.0895 - val_accuracy: 0.9625 - val_precision: 0.9932 - val_recall: 0.9554
# Epoch 14/25
# 261/261 [==============================] - 59s 226ms/step - loss: 0.1383 - accuracy: 0.9393 - precision: 0.9845 - recall: 0.9335 - val_loss: 0.1525 - val_accuracy: 0.9327 - val_precision: 0.9971 - val_recall: 0.9109
# Epoch 15/25
# 261/261 [==============================] - 59s 227ms/step - loss: 0.1318 - accuracy: 0.9484 - precision: 0.9908 - recall: 0.9403 - val_loss: 0.0403 - val_accuracy: 0.9846 - val_precision: 0.9921 - val_recall: 0.9869
# Epoch 16/25
# 261/261 [==============================] - 58s 224ms/step - loss: 0.1131 - accuracy: 0.9554 - precision: 0.9917 - recall: 0.9481 - val_loss: 0.0587 - val_accuracy: 0.9798 - val_precision: 0.9920 - val_recall: 0.9803
# Epoch 17/25
# 261/261 [==============================] - 59s 226ms/step - loss: 0.1164 - accuracy: 0.9632 - precision: 0.9884 - recall: 0.9610 - val_loss: 0.1836 - val_accuracy: 0.9317 - val_precision: 1.0000 - val_recall: 0.9069
# Epoch 18/25
# 261/261 [==============================] - 60s 232ms/step - loss: 0.1047 - accuracy: 0.9594 - precision: 0.9920 - recall: 0.9543 - val_loss: 0.0716 - val_accuracy: 0.9750 - val_precision: 0.9829 - val_recall: 0.9829
# Epoch 19/25
# 261/261 [==============================] - 60s 232ms/step - loss: 0.0961 - accuracy: 0.9619 - precision: 0.9934 - recall: 0.9556 - val_loss: 0.0889 - val_accuracy: 0.9721 - val_precision: 0.9779 - val_recall: 0.9843
# Epoch 20/25
# 261/261 [==============================] - 60s 232ms/step - loss: 0.0987 - accuracy: 0.9655 - precision: 0.9910 - recall: 0.9626 - val_loss: 0.1685 - val_accuracy: 0.9269 - val_precision: 0.9985 - val_recall: 0.9017
# Epoch 21/25
# 261/261 [==============================] - 59s 228ms/step - loss: 0.1030 - accuracy: 0.9611 - precision: 0.9912 - recall: 0.9562 - val_loss: 0.0962 - val_accuracy: 0.9577 - val_precision: 0.9986 - val_recall: 0.9435
# Epoch 22/25
# 261/261 [==============================] - 60s 229ms/step - loss: 0.1017 - accuracy: 0.9639 - precision: 0.9908 - recall: 0.9608 - val_loss: 0.0603 - val_accuracy: 0.9827 - val_precision: 0.9782 - val_recall: 0.9987
# Epoch 23/25
# 261/261 [==============================] - 62s 236ms/step - loss: 0.0759 - accuracy: 0.9720 - precision: 0.9931 - recall: 0.9693 - val_loss: 0.0566 - val_accuracy: 0.9798 - val_precision: 0.9805 - val_recall: 0.9921
# Epoch 24/25
# 261/261 [==============================] - 59s 228ms/step - loss: 0.0837 - accuracy: 0.9732 - precision: 0.9945 - recall: 0.9696 - val_loss: 0.0616 - val_accuracy: 0.9740 - val_precision: 0.9946 - val_recall: 0.9699
# Epoch 25/25
# 261/261 [==============================] - 59s 228ms/step - loss: 0.0932 - accuracy: 0.9648 - precision: 0.9909 - recall: 0.9621 - val_loss: 0.0936 - val_accuracy: 0.9567 - val_precision: 0.9972 - val_recall: 0.9436

# %% [markdown]
# ### 결과 확인
# ---
# 그래프를 비교해보았습니다.

# %% [markdown]
# #### dropout을 적용 안 한 모델 vs dropout을 적용한 모델 - 두 모델 모두 augmentation은 적용
# ---
# accuracy를 기준으로 봤을 때 두 모델의 진폭이 낮아지므로, 수렴한다고 파악되어집니다.\
# 다만, recall의 경우에는 수렴한다고 보기 어려운 모습을 보이는 것 같습니다.

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].plot(history_nodrop_aug.history[met])
    ax[i].plot(history_nodrop_aug.history['val_' + met])    
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val', 'nodrop_train', 'nodrop_val'])

# %% [markdown]
# #### augmentatiom을 적용 안 한 모델 vs augmentation을 적용한 모델 - 두 모델 모두 dropout은 적용
# ---
# augmentation을 적용하지 않은 모델의 경우 중간의 peak이 매우 커서 수렴여부가 의심스럽습니다.\
# 더불어 여전히 recall값의 수렴여부는 판단하기 어렵습니다.

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].plot(history_noaug.history[met])
    ax[i].plot(history_noaug.history['val_' + met])    
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val', 'noaug_train', 'noaug_val'])

# %% [markdown]
# ### 최종결과(evaluate)
# ---
# augmentation을 적용하고 dropout을 적용하지 않은 모델이 첫 번째로, 0.83의 값을 보였습니다.\
# augmentation을 적용하지 않고 dropout이 적용된 모델이 두 번째, 0.77의 값을 보였습니다.\
# augmentation과 dropout을 모두 적용한 모델이 세 번째, 0.85의 값을 보였습니다.

# %%
loss, accuracy, precision, recall = model_nodrop_aug.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 39/39 [==============================] - 6s 147ms/step - loss: 0.9473 - accuracy: 0.8317 - precision: 0.7987 - recall: 0.9769
# Loss: 0.9473440647125244,
# Accuracy: 0.8317307829856873,
# Precision: 0.7987421154975891,
# Recall: 0.9769230484962463

# %%
loss, accuracy, precision, recall = model_noaug.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 39/39 [==============================] - 6s 148ms/step - loss: 1.0505 - accuracy: 0.7772 - precision: 0.7390 - recall: 0.9949
# Loss: 1.0504859685897827,
# Accuracy: 0.7772436141967773,
# Precision: 0.739047646522522,
# Recall: 0.9948717951774597

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 39/39 [==============================] - 6s 151ms/step - loss: 0.7094 - accuracy: 0.8510 - precision: 0.8221 - recall: 0.9718
# Loss: 0.7093735337257385,
# Accuracy: 0.8509615659713745,
# Precision: 0.8221257925033569,
# Recall: 0.971794843673706

# %% [markdown]
# ### 회고
# ---
# 기존 방법에 augmentation을 적용한 모델만이 무사히 0.85이상의 값을 보일 수 있었습니다만,\
# 종종 0.85이하의 값이 최종결과로 나오곤 하여서, 다른 시도를 해봤지만 그 이상의 값을 얻을 수는 없었습니다.\
# 시도했던 것은 optimization을 RMSprop, nadam 등으로 변경해 보는 것과 dropout의 숫자를 변경하는 것, epoch값을 증감시켜보는 것이었습니다.\
# dropout의 값은 0.4까지는 뚜렷한 변화가 없다가 0.5이상부터 accuracy의 감소를 확인할 수 있었습니다.
# 모델의 학습속도가 있기에 성능개선의 어려움을 새삼 체감할 수 있던 노드였습니다.
