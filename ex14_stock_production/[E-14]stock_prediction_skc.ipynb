# %% [markdown]
# ### 필요 패키지 import
# ---
# 사용되는 패키지들을 import합니다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA

from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## SAMSUNG
# ---
# 삼성 데이터 이용

# %% [markdown]
# ### 데이터 가져오기
# ---
# 필요 데이터(날짜, 종가)를 불러오고 확인합니다.

# %%
dataset_filepath = os.getenv('HOME') + '/aiffel/stock_prediction/data/005930.KS.csv'
df = pd.read_csv(dataset_filepath, index_col='Date', parse_dates=True)
ts = df['Close']

ts.head()
# Out:
# Date
# 2020-05-18    48800.0
# 2020-05-19    50300.0
# 2020-05-20    50000.0
# 2020-05-21    49950.0
# 2020-05-22    48750.0
# Name: Close, dtype: float64

# %% [markdown]
# ### 전처리 수행
# ---
# 결측치를 처리 한 뒤, 이를 로그변환 합니다.

# %%
ts=ts.interpolate(method='time')
ts_log = np.log(ts)
ts[ts.isna()]  # Time Series에서 결측치가 있는 부분만 Series로 출력합니다.
# Out:
# Series([], Name: Close, dtype: float64)

# %% [markdown]
# ### 시계열 안정성 분석(EDA)
# ---
# 정성적, 정량적 그래프 분석 및 시계열 분해, 안정성 확인을 진행했습니다.

# %%
def plot_rolling_statistics(timeseries, window=12):
    
    rolmean = timeseries.rolling(window=window).mean()  
    rolstd = timeseries.rolling(window=window).std()

    orig = plt.plot(timeseries, color='blue',label='Original')    
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)

# %%
def augmented_dickey_fuller_test(timeseries):
    dftest = adfuller(timeseries, autolag='AIC')  
    
    print('Results of Dickey-Fuller Test:')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)

#시계열 분해 (Time Series Decomposition)
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.383525
# p-value                          0.590149
# #Lags Used                       0.000000
# Number of Observations Used    249.000000
# Critical Value (1%)             -3.456888
# Critical Value (5%)             -2.873219
# Critical Value (10%)            -2.572994
# dtype: float64

# %%
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -6.187586e+00
# p-value                        6.234854e-08
# #Lags Used                     9.000000e+00
# Number of Observations Used    2.100000e+02
# Critical Value (1%)           -3.461879e+00
# Critical Value (5%)           -2.875404e+00
# Critical Value (10%)          -2.574159e+00
# dtype: float64

# %% [markdown]
# ### 학습, 테스트 데이터셋 생성
# ---
# 훈련 자료와 시험 자료를 나눕니다.

# %%
train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %% [markdown]
# ### 적정 ARIMA 모수 산출
# ---
# ACF, PACF 그리고 p,q 구합니다.\
# 차분 안정성을 확인하여 d를 구합니다.

# %%
plot_acf(ts_log)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_log)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()

# %%
# 1차 차분 구하기
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.553699e+01
# p-value                        2.183738e-28
# #Lags Used                     0.000000e+00
# Number of Observations Used    2.480000e+02
# Critical Value (1%)           -3.456996e+00
# Critical Value (5%)           -2.873266e+00
# Critical Value (10%)          -2.573019e+00
# dtype: float64

# %%
# 혹시 필요한 경우 2차 차분 구하기
diff_2 = diff_1.diff(periods=1).iloc[1:]
diff_2.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.029320e+01
# p-value                        3.525823e-18
# #Lags Used                     7.000000e+00
# Number of Observations Used    2.400000e+02
# Critical Value (1%)           -3.457894e+00
# Critical Value (5%)           -2.873659e+00
# Critical Value (10%)          -2.573229e+00
# dtype: float64

# %% [markdown]
# ### ARIMA 모델 훈련 및 검증
# ---
# 모델을 훈련하고 정확도를 측정했습니다.

# %%
# Build Model
model = ARIMA(train_data, order=(9, 1, 0))  
fitted_m = model.fit(disp=-1)  
print(fitted_m.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Close   No. Observations:                  224
# Model:                 ARIMA(9, 1, 0)   Log Likelihood                 586.601
# Method:                       css-mle   S.D. of innovations              0.018
# Date:                Thu, 18 Nov 2021   AIC                          -1151.202
# Time:                        18:00:41   BIC                          -1113.673
# Sample:                             1   HQIC                         -1136.053
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0024      0.001      2.034      0.042    8.76e-05       0.005
# ar.L1.D.Close     0.0162      0.067      0.242      0.809      -0.115       0.147
# ar.L2.D.Close    -0.0306      0.067     -0.458      0.647      -0.162       0.100
# ar.L3.D.Close    -0.0516      0.067     -0.772      0.440      -0.182       0.079
# ar.L4.D.Close     0.0014      0.067      0.020      0.984      -0.130       0.133
# ar.L5.D.Close    -0.0236      0.067     -0.352      0.725      -0.155       0.108
# ar.L6.D.Close    -0.0215      0.067     -0.322      0.747      -0.152       0.109
# ar.L7.D.Close     0.0435      0.067      0.651      0.515      -0.087       0.174
# ar.L8.D.Close     0.0016      0.067      0.024      0.981      -0.129       0.133
# ar.L9.D.Close     0.0667      0.067      1.000      0.318      -0.064       0.198
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.3535           -0.0000j            1.3535           -0.0000
# AR.2            0.9671           -0.8751j            1.3042           -0.1171
# AR.3            0.9671           +0.8751j            1.3042            0.1171
# AR.4           -1.2229           -0.4648j            1.3083           -0.4422
# AR.5           -1.2229           +0.4648j            1.3083            0.4422
# AR.6           -0.6339           -1.2565j            1.4074           -0.3244
# AR.7           -0.6339           +1.2565j            1.4074            0.3244
# AR.8            0.2011           -1.3712j            1.3859           -0.2268
# AR.9            0.2011           +1.3712j            1.3859            0.2268
# -----------------------------------------------------------------------------

# %%
# Forecast : 결과가 fc에 담깁니다. 
fc, se, conf = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과
lower_series = pd.Series(conf[:, 0], index=test_data.index)  # 예측결과의 하한 바운드
upper_series = pd.Series(conf[:, 1], index=test_data.index)  # 예측결과의 상한 바운드

# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.10)
plt.legend()
plt.show()

# %%
mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  24288243.959584832
# MAE:  4042.792420705489
# RMSE:  4928.310456899487
# MAPE: 4.99%

# %% [markdown]
# ## airline-passengers
# ---
# 주어진 데이터는 주가가 아니라 승객수지만 진행해보았습니다.

# %% [markdown]
# ### 데이터 가져오기

# %%
dataset_filepath = os.getenv('HOME') + '/aiffel/stock_prediction/data/airline-passengers.csv'
df = pd.read_csv(dataset_filepath, index_col='Month', parse_dates=True)
ts = df['Passengers']

ts.head()
# Out:
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
# Name: Passengers, dtype: int64

# %% [markdown]
# ### 전처리 수행

# %%
ts=ts.interpolate(method='time')
ts_log = np.log(ts)
ts[ts.isna()]  # Time Series에서 결측치가 있는 부분만 Series로 출력합니다.
# Out:
# Series([], Name: Passengers, dtype: int64)

# %% [markdown]
# ### 시계열 안정성 분석

# %%
def plot_rolling_statistics(timeseries, window=12):
    
    rolmean = timeseries.rolling(window=window).mean()  
    rolstd = timeseries.rolling(window=window).std()

    orig = plt.plot(timeseries, color='blue',label='Original')    
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)

# %%
def augmented_dickey_fuller_test(timeseries):
    dftest = adfuller(timeseries, autolag='AIC')  
    
    print('Results of Dickey-Fuller Test:')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)

#시계열 분해 (Time Series Decomposition)
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.717017
# p-value                          0.422367
# #Lags Used                      13.000000
# Number of Observations Used    130.000000
# Critical Value (1%)             -3.481682
# Critical Value (5%)             -2.884042
# Critical Value (10%)            -2.578770
# dtype: float64

# %% [markdown]
# ### 학습, 테스트 데이터셋 생성

# %%
train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %% [markdown]
# ### 적정 ARIMA 모수 산출

# %%
plot_acf(ts_log)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_log)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()

# %%
# 1차 차분 구하기
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.717131
# p-value                          0.071121
# #Lags Used                      14.000000
# Number of Observations Used    128.000000
# Critical Value (1%)             -3.482501
# Critical Value (5%)             -2.884398
# Critical Value (10%)            -2.578960
# dtype: float64

# %%
# 혹시 필요한 경우 2차 차분 구하기
diff_2 = diff_1.diff(periods=1).iloc[1:]
diff_2.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.196629e+00
# p-value                        7.419305e-13
# #Lags Used                     1.300000e+01
# Number of Observations Used    1.280000e+02
# Critical Value (1%)           -3.482501e+00
# Critical Value (5%)           -2.884398e+00
# Critical Value (10%)          -2.578960e+00
# dtype: float64

# %% [markdown]
# ### ARIMA 모델 훈련 및 검증

# %%
# Build Model
model = ARIMA(train_data, order=(14, 1, 0))  
fitted_m = model.fit(disp=-1)  
print(fitted_m.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:           D.Passengers   No. Observations:                  128
# Model:                ARIMA(14, 1, 0)   Log Likelihood                 224.800
# Method:                       css-mle   S.D. of innovations              0.039
# Date:                Thu, 18 Nov 2021   AIC                           -417.600
# Time:                        17:34:12   BIC                           -371.967
# Sample:                    02-01-1949   HQIC                          -399.059
#                          - 09-01-1959
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.0099      0.001      7.014      0.000       0.007       0.013
# ar.L1.D.Passengers     -0.3400      0.089     -3.808      0.000      -0.515      -0.165
# ar.L2.D.Passengers     -0.1271      0.092     -1.379      0.168      -0.308       0.054
# ar.L3.D.Passengers     -0.1646      0.071     -2.316      0.021      -0.304      -0.025
# ar.L4.D.Passengers     -0.2652      0.072     -3.680      0.000      -0.406      -0.124
# ar.L5.D.Passengers     -0.1349      0.073     -1.852      0.064      -0.278       0.008
# ar.L6.D.Passengers     -0.2264      0.071     -3.193      0.001      -0.365      -0.087
# ar.L7.D.Passengers     -0.1775      0.071     -2.500      0.012      -0.317      -0.038
# ar.L8.D.Passengers     -0.2744      0.071     -3.856      0.000      -0.414      -0.135
# ar.L9.D.Passengers     -0.1402      0.073     -1.912      0.056      -0.284       0.004
# ar.L10.D.Passengers    -0.2479      0.073     -3.387      0.001      -0.391      -0.104
# ar.L11.D.Passengers    -0.1215      0.072     -1.676      0.094      -0.263       0.021
# ar.L12.D.Passengers     0.6483      0.072      8.992      0.000       0.507       0.790
# ar.L13.D.Passengers     0.2246      0.095      2.367      0.018       0.039       0.411
# ar.L14.D.Passengers    -0.1293      0.092     -1.401      0.161      -0.310       0.052
#                                     Roots
# ==============================================================================
#                    Real          Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# AR.1            -0.5029           -0.8743j            1.0086           -0.3331
# AR.2            -0.5029           +0.8743j            1.0086            0.3331
# AR.3            -0.8839           -0.5182j            1.0246           -0.4156
# AR.4            -0.8839           +0.5182j            1.0246            0.4156
# AR.5            -1.2185           -0.0000j            1.2185           -0.5000
# AR.6            -1.4415           -0.0000j            1.4415           -0.5000
# AR.7             0.0098           -1.0113j            1.0113           -0.2485
# AR.8             0.0098           +1.0113j            1.0113            0.2485
# AR.9             0.4986           -0.8702j            1.0029           -0.1672
# AR.10            0.4986           +0.8702j            1.0029            0.1672
# AR.11            0.8694           -0.5005j            1.0032           -0.0831
# AR.12            0.8694           +0.5005j            1.0032            0.0831
# AR.13            1.2633           -0.0000j            1.2633           -0.0000
# AR.14            3.1518           -0.0000j            3.1518           -0.0000
# ------------------------------------------------------------------------------

# %%
# Forecast : 결과가 fc에 담깁니다. 
fc, se, conf = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과
lower_series = pd.Series(conf[:, 0], index=test_data.index)  # 예측결과의 하한 바운드
upper_series = pd.Series(conf[:, 1], index=test_data.index)  # 예측결과의 상한 바운드

# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.10)
plt.legend()
plt.show()

# %%
mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  161.97365315017063
# MAE:  9.824151885161625
# RMSE:  12.72688701726273
# MAPE: 2.18%

# %% [markdown]
# ## daily-min-tempratures
# ---
# 주어진 데이터는 주가가 아니라 온도였지만 진행해보았습니다.

# %% [markdown]
# ### 데이터 가져오기

# %%
dataset_filepath = os.getenv('HOME') + '/aiffel/stock_prediction/data/daily-min-temperatures.csv'
df = pd.read_csv(dataset_filepath, index_col='Date', parse_dates=True)
ts = df['Temp']

ts.head()
# ts.isnull().values.any()
# Out:
# Date
# 1981-01-01    20.7
# 1981-01-02    17.9
# 1981-01-03    18.8
# 1981-01-04    14.6
# 1981-01-05    15.8
# Name: Temp, dtype: float64

# %% [markdown]
# ### 전처리 수행

# %%
ts=ts.interpolate(method='time')
ts_log = np.log(ts)
# ts[ts.isna()]  # Time Series에서 결측치가 있는 부분만 Series로 출력합니다.
# ts_log = ts_log.dropna(axis=0)
# ts_log.isnull().values.any()
# plt.plot(ts_log)
ts_log.isna().sum()
# ts_log.dropna(inplace=True)
# ts.isna().sum()
# Out:
# 0

# %% [markdown]
# ### 시계열 안정성 분석

# %%
def plot_rolling_statistics(timeseries, window=12):
    
    rolmean = timeseries.rolling(window=window).mean()  
    rolstd = timeseries.rolling(window=window).std()

    orig = plt.plot(timeseries, color='blue',label='Original')    
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)

# %%
def augmented_dickey_fuller_test(timeseries):
    # statsmodels 패키지에서 제공하는 adfuller 메소드를 호출합니다.
    print(timeseries.shape)
    print(f'결측치: {timeseries.isna().sum()}')
    dftest = adfuller(timeseries, autolag='AIC')  
    
    # adfuller 메소드가 리턴한 결과를 정리하여 출력합니다.
    print('Results of Dickey-Fuller Test:')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %%
plot_rolling_statistics(ts_log, window=12)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)

decomposition = seasonal_decompose(residual, model='multiplicative', period = 30)
# Out:
# (190,)
# 결측치: 0
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.823601
# p-value                          0.000049
# #Lags Used                      13.000000
# Number of Observations Used    176.000000
# Critical Value (1%)             -3.468062
# Critical Value (5%)             -2.878106
# Critical Value (10%)            -2.575602
# dtype: float64

# %%
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)
# Out:
# (190,)
# 결측치: 0
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.823601
# p-value                          0.000049
# #Lags Used                      13.000000
# Number of Observations Used    176.000000
# Critical Value (1%)             -3.468062
# Critical Value (5%)             -2.878106
# Critical Value (10%)            -2.575602
# dtype: float64

# %% [markdown]
# ### 학습, 테스트 데이터셋 생성

# %%
train_data, test_data = residual[:int(len(residual)*0.9)], residual[int(len(residual)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(residual, c='r', label='training dataset')
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %% [markdown]
# ### 적정 ARIMA 모수 산출

# %%
print(ts_log[2])
plot_acf(residual)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(residual)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()
# Out:
# 2.9338568698359038

# %%
# 1차 차분 구하기
diff_1 = residual.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)
# Out:
# (189,)
# 결측치: 0
# Results of Dickey-Fuller Test:
# Test Statistic                -7.325956e+00
# p-value                        1.160932e-10
# #Lags Used                     1.400000e+01
# Number of Observations Used    1.740000e+02
# Critical Value (1%)           -3.468502e+00
# Critical Value (5%)           -2.878298e+00
# Critical Value (10%)          -2.575704e+00
# dtype: float64

# %%
# 혹시 필요한 경우 2차 차분 구하기
diff_2 = diff_1.diff(periods=1).iloc[1:]
diff_2.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# (188,)
# 결측치: 0
# Results of Dickey-Fuller Test:
# Test Statistic                -6.903327e+00
# p-value                        1.265592e-09
# #Lags Used                     1.500000e+01
# Number of Observations Used    1.720000e+02
# Critical Value (1%)           -3.468952e+00
# Critical Value (5%)           -2.878495e+00
# Critical Value (10%)          -2.575809e+00
# dtype: float64

# %% [markdown]
# ### ARIMA 모델 훈련 및 검증

# %%
# Build Model
model = ARIMA(train_data, order=(15, 1, 0))  
fitted_m = model.fit(disp=-1)  
print(fitted_m.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.resid   No. Observations:                  170
# Model:                ARIMA(15, 1, 0)   Log Likelihood                 894.821
# Method:                       css-mle   S.D. of innovations              0.001
# Date:                Thu, 18 Nov 2021   AIC                          -1755.642
# Time:                        18:07:43   BIC                          -1702.333
# Sample:                             1   HQIC                         -1734.010
#
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const          -1.433e-06   3.21e-05     -0.045      0.964   -6.44e-05    6.15e-05
# ar.L1.D.resid     -0.0734      0.076     -0.965      0.335      -0.222       0.076
# ar.L2.D.resid     -0.2315      0.075     -3.084      0.002      -0.379      -0.084
# ar.L3.D.resid     -0.1225      0.071     -1.725      0.085      -0.262       0.017
# ar.L4.D.resid     -0.0202      0.071     -0.284      0.776      -0.159       0.119
# ar.L5.D.resid     -0.1693      0.070     -2.403      0.016      -0.307      -0.031
# ar.L6.D.resid     -0.1263      0.068     -1.858      0.063      -0.259       0.007
# ar.L7.D.resid     -0.0270      0.069     -0.391      0.696      -0.162       0.108
# ar.L8.D.resid     -0.1152      0.070     -1.657      0.098      -0.251       0.021
# ar.L9.D.resid      0.0731      0.070      1.046      0.295      -0.064       0.210
# ar.L10.D.resid    -0.2871      0.069     -4.153      0.000      -0.423      -0.152
# ar.L11.D.resid    -0.1390      0.072     -1.931      0.053      -0.280       0.002
# ar.L12.D.resid    -0.1439      0.073     -1.974      0.048      -0.287      -0.001
# ar.L13.D.resid    -0.3624      0.073     -4.948      0.000      -0.506      -0.219
# ar.L14.D.resid    -0.1375      0.078     -1.774      0.076      -0.290       0.014
# ar.L15.D.resid    -0.1892      0.078     -2.427      0.015      -0.342      -0.036
#                                     Roots
# ==============================================================================
#                    Real          Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# AR.1             0.9820           -0.2935j            1.0249           -0.0462
# AR.2             0.9820           +0.2935j            1.0249            0.0462
# AR.3             0.7692           -0.7097j            1.0466           -0.1186
# AR.4             0.7692           +0.7097j            1.0466            0.1186
# AR.5             0.4668           -1.0415j            1.1414           -0.1829
# AR.6             0.4668           +1.0415j            1.1414            0.1829
# AR.7            -0.9715           -0.4166j            1.0571           -0.4355
# AR.8            -0.9715           +0.4166j            1.0571            0.4355
# AR.9            -1.1528           -0.0000j            1.1528           -0.5000
# AR.10           -0.0043           -1.0952j            1.0952           -0.2506
# AR.11           -0.0043           +1.0952j            1.0952            0.2506
# AR.12           -0.6176           -0.9182j            1.1066           -0.3442
# AR.13           -0.6176           +0.9182j            1.1066            0.3442
# AR.14           -0.4118           -1.3017j            1.3653           -0.2988
# AR.15           -0.4118           +1.3017j            1.3653            0.2988
# ------------------------------------------------------------------------------

# %%
# Forecast : 결과가 fc에 담깁니다. 
fc, se, conf = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과
lower_series = pd.Series(conf[:, 0], index=test_data.index)  # 예측결과의 하한 바운드
upper_series = pd.Series(conf[:, 1], index=test_data.index)  # 예측결과의 상한 바운드

# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.10)
plt.legend()
plt.show()

# %%
mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  1.4242897197909413e-05
# MAE:  0.0032879150682573596
# RMSE:  0.003773976311254406
# MAPE: 0.12%

# %% [markdown]
# ## HMM
# ---
# 혹시 종목이 주가가 있는 종목을 의미할 지도 모른다고 생각하여 추가했습니다.\
# 제 친구가 좋아하는 주식입니다.

# %% [markdown]
# ### 데이터 가져오기

# %%
dataset_filepath = os.getenv('HOME') + '/aiffel/stock_prediction/data/HMM011200.KS.csv'
df = pd.read_csv(dataset_filepath, index_col='Date', parse_dates=True)
ts = df['Close']

ts.head()
# Out:
# Date
# 2020-11-18    13150.0
# 2020-11-19    12550.0
# 2020-11-20    12750.0
# 2020-11-23    13400.0
# 2020-11-24    13050.0
# Name: Close, dtype: float64

# %% [markdown]
# ### 전처리 수행

# %%
ts=ts.interpolate(method='time')
ts_log = np.log(ts)
ts[ts.isna()]  # Time Series에서 결측치가 있는 부분만 Series로 출력합니다.
# Out:
# Series([], Name: Close, dtype: float64)

# %% [markdown]
# ### 시계열 안정성 분석

# %%
def plot_rolling_statistics(timeseries, window=12):
    
    rolmean = timeseries.rolling(window=window).mean()  
    rolstd = timeseries.rolling(window=window).std()

    orig = plt.plot(timeseries, color='blue',label='Original')    
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
def augmented_dickey_fuller_test(timeseries):
    # statsmodels 패키지에서 제공하는 adfuller 메소드를 호출합니다.
#     print(timeseries.shape)
#     print(f'결측치: {timeseries.isna().sum()}')
    dftest = adfuller(timeseries, autolag='AIC')  
    
    # adfuller 메소드가 리턴한 결과를 정리하여 출력합니다.
    print('Results of Dickey-Fuller Test:')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)

#시계열 분해 (Time Series Decomposition)
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.667724
# p-value                          0.447814
# #Lags Used                       0.000000
# Number of Observations Used    246.000000
# Critical Value (1%)             -3.457215
# Critical Value (5%)             -2.873362
# Critical Value (10%)            -2.573070
# dtype: float64

# %%
residual.dropna(inplace=True)
augmented_dickey_fuller_test(residual)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -5.859396e+00
# p-value                        3.438775e-07
# #Lags Used                     3.000000e+00
# Number of Observations Used    2.130000e+02
# Critical Value (1%)           -3.461429e+00
# Critical Value (5%)           -2.875207e+00
# Critical Value (10%)          -2.574054e+00
# dtype: float64

# %% [markdown]
# ### 학습, 테스트 데이터셋 생성

# %%
train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %% [markdown]
# ### 적정 ARIMA 모수 산출

# %%
plot_acf(ts_log)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_log)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()

# %%
# 1차 차분 구하기
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.576780e+01
# p-value                        1.170783e-28
# #Lags Used                     0.000000e+00
# Number of Observations Used    2.450000e+02
# Critical Value (1%)           -3.457326e+00
# Critical Value (5%)           -2.873410e+00
# Critical Value (10%)          -2.573096e+00
# dtype: float64

# %%
# 혹시 필요한 경우 2차 차분 구하기
diff_2 = diff_1.diff(periods=1).iloc[1:]
diff_2.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.156702e+00
# p-value                        9.377969e-13
# #Lags Used                     1.300000e+01
# Number of Observations Used    2.310000e+02
# Critical Value (1%)           -3.458980e+00
# Critical Value (5%)           -2.874135e+00
# Critical Value (10%)          -2.573482e+00
# dtype: float64

# %% [markdown]
# ### ARIMA 모델 훈련 및 검증

# %%
# Build Model
model = ARIMA(train_data, order=(24, 1, 0))  
fitted_m = model.fit(disp=-1)  
print(fitted_m.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Close   No. Observations:                  221
# Model:                ARIMA(24, 1, 0)   Log Likelihood                 415.453
# Method:                       css-mle   S.D. of innovations              0.037
# Date:                Thu, 18 Nov 2021   AIC                           -778.907
# Time:                        18:20:18   BIC                           -690.554
# Sample:                             1   HQIC                          -743.231
#
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0021      0.005      0.429      0.668      -0.007       0.012
# ar.L1.D.Close     -0.0487      0.067     -0.721      0.471      -0.181       0.084
# ar.L2.D.Close      0.0521      0.067      0.773      0.440      -0.080       0.184
# ar.L3.D.Close      0.1075      0.068      1.572      0.116      -0.027       0.241
# ar.L4.D.Close     -0.0641      0.069     -0.930      0.353      -0.199       0.071
# ar.L5.D.Close     -0.0294      0.069     -0.423      0.672      -0.166       0.107
# ar.L6.D.Close     -0.0686      0.069     -0.994      0.320      -0.204       0.067
# ar.L7.D.Close      0.0274      0.070      0.394      0.694      -0.109       0.164
# ar.L8.D.Close      0.1344      0.070      1.909      0.056      -0.004       0.272
# ar.L9.D.Close      0.1018      0.071      1.430      0.153      -0.038       0.241
# ar.L10.D.Close    -0.1015      0.071     -1.419      0.156      -0.242       0.039
# ar.L11.D.Close     0.0446      0.071      0.628      0.530      -0.095       0.184
# ar.L12.D.Close     0.0565      0.071      0.798      0.425      -0.082       0.195
# ar.L13.D.Close     0.1344      0.071      1.890      0.059      -0.005       0.274
# ar.L14.D.Close     0.0653      0.072      0.911      0.362      -0.075       0.206
# ar.L15.D.Close     0.0532      0.072      0.744      0.457      -0.087       0.194
# ar.L16.D.Close     0.0286      0.072      0.399      0.690      -0.112       0.169
# ar.L17.D.Close     0.0373      0.070      0.530      0.596      -0.101       0.175
# ar.L18.D.Close    -0.0047      0.071     -0.067      0.947      -0.143       0.134
# ar.L19.D.Close    -0.0728      0.070     -1.037      0.300      -0.210       0.065
# ar.L20.D.Close    -0.0718      0.070     -1.025      0.305      -0.209       0.065
# ar.L21.D.Close    -0.0269      0.071     -0.381      0.703      -0.165       0.111
# ar.L22.D.Close     0.0770      0.070      1.100      0.271      -0.060       0.214
# ar.L23.D.Close     0.0484      0.070      0.689      0.491      -0.089       0.186
# ar.L24.D.Close     0.0160      0.070      0.227      0.821      -0.122       0.154
#                                     Roots
# ==============================================================================
#                    Real          Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# AR.1             1.0550           -0.0000j            1.0550           -0.0000
# AR.2             0.9268           -0.5093j            1.0575           -0.0800
# AR.3             0.9268           +0.5093j            1.0575            0.0800
# AR.4             1.1596           -0.3009j            1.1980           -0.0404
# AR.5             1.1596           +0.3009j            1.1980            0.0404
# AR.6             0.7181           -0.7688j            1.0520           -0.1304
# AR.7             0.7181           +0.7688j            1.0520            0.1304
# AR.8             0.5069           -0.9830j            1.1060           -0.1742
# AR.9             0.5069           +0.9830j            1.1060            0.1742
# AR.10            0.1234           -1.0746j            1.0817           -0.2318
# AR.11            0.1234           +1.0746j            1.0817            0.2318
# AR.12           -0.1339           -1.1248j            1.1327           -0.2689
# AR.13           -0.1339           +1.1248j            1.1327            0.2689
# AR.14           -0.4965           -1.0690j            1.1786           -0.3192
# AR.15           -0.4965           +1.0690j            1.1786            0.3192
# AR.16           -0.7173           -0.8616j            1.1211           -0.3605
# AR.17           -0.7173           +0.8616j            1.1211            0.3605
# AR.18           -1.2165           -0.0000j            1.2165           -0.5000
# AR.19           -1.0588           -0.3201j            1.1061           -0.4533
# AR.20           -1.0588           +0.3201j            1.1061            0.4533
# AR.21           -0.9666           -0.6687j            1.1753           -0.4037
# AR.22           -0.9666           +0.6687j            1.1753            0.4037
# AR.23           -1.4941           -1.6824j            2.2501           -0.3656
# AR.24           -1.4941           +1.6824j            2.2501            0.3656
# ------------------------------------------------------------------------------

# %%
# Forecast : 결과가 fc에 담깁니다. 
fc, se, conf = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과
lower_series = pd.Series(conf[:, 0], index=test_data.index)  # 예측결과의 하한 바운드
upper_series = pd.Series(conf[:, 1], index=test_data.index)  # 예측결과의 상한 바운드

# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.10)
plt.legend()
plt.show()

# %%
mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  3802208.0662109065
# MAE:  1814.3358121280571
# RMSE:  1949.9251437454993
# MAPE: 6.50%

# %% [markdown]
# ## NVDA
# ---
# 주가가 있는 종목을 의미할 지도 모른다고 생각하여 추가했습니다.

# %% [markdown]
# ### 데이터 가져오기

# %%
dataset_filepath = os.getenv('HOME') + '/aiffel/stock_prediction/data/NVDA.csv'
df = pd.read_csv(dataset_filepath, index_col='Date', parse_dates=True)
ts = df['Close']

ts.head()
# Out:
# Date
# 2020-11-17    134.222504
# 2020-11-18    134.287506
# 2020-11-19    134.402496
# 2020-11-20    130.877502
# 2020-11-23    131.399994
# Name: Close, dtype: float64

# %% [markdown]
# ### 전처리 수행

# %%
ts=ts.interpolate(method='time')
ts_log = np.log(ts)
ts[ts.isna()]  # Time Series에서 결측치가 있는 부분만 Series로 출력합니다.
# Out:
# Series([], Name: Close, dtype: float64)

# %% [markdown]
# ### 시계열 안정성 분석

# %%
# 정성적 그래프 분석
plot_rolling_statistics(ts_log, window=12)

#정량적 Augmented Dicky-Fuller Test
augmented_dickey_fuller_test(ts_log)

#시계열 분해 (Time Series Decomposition)
decomposition = seasonal_decompose(ts_log, model='multiplicative', period = 30) 

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_log, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   0.483158
# p-value                          0.984352
# #Lags Used                       0.000000
# Number of Observations Used    252.000000
# Critical Value (1%)             -3.456569
# Critical Value (5%)             -2.873079
# Critical Value (10%)            -2.572919
# dtype: float64

# %% [markdown]
# ### 학습, 테스트 데이터셋 생성

# %%
train_data, test_data = ts_log[:int(len(ts_log)*0.9)], ts_log[int(len(ts_log)*0.9):]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.plot(ts_log, c='r', label='training dataset')
plt.plot(test_data, c='b', label='test dataset')
plt.legend()

# %% [markdown]
# ### 적정 ARIMA 모수 산출

# %%
plot_acf(ts_log)   # ACF : Autocorrelation 그래프 그리기
plot_pacf(ts_log)  # PACF : Partial Autocorrelation 그래프 그리기
plt.show()

# %%
# 1차 차분 구하기
diff_1 = ts_log.diff(periods=1).iloc[1:]
diff_1.plot(title='Difference 1st')

augmented_dickey_fuller_test(diff_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.655915e+01
# p-value                        1.914213e-29
# #Lags Used                     0.000000e+00
# Number of Observations Used    2.510000e+02
# Critical Value (1%)           -3.456674e+00
# Critical Value (5%)           -2.873125e+00
# Critical Value (10%)          -2.572944e+00
# dtype: float64

# %%
# 혹시 필요한 경우 2차 차분 구하기
diff_2 = diff_1.diff(periods=1).iloc[1:]
diff_2.plot(title='Difference 2nd')

augmented_dickey_fuller_test(diff_2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.178259e+01
# p-value                        1.026466e-21
# #Lags Used                     5.000000e+00
# Number of Observations Used    2.450000e+02
# Critical Value (1%)           -3.457326e+00
# Critical Value (5%)           -2.873410e+00
# Critical Value (10%)          -2.573096e+00
# dtype: float64

# %% [markdown]
# ### ARIMA 모델 훈련 및 검증

# %%
# Build Model
model = ARIMA(train_data, order=(21, 1, 0))  
fitted_m = model.fit(disp=-1)  
print(fitted_m.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Close   No. Observations:                  226
# Model:                ARIMA(21, 1, 0)   Log Likelihood                 527.616
# Method:                       css-mle   S.D. of innovations              0.023
# Date:                Thu, 18 Nov 2021   AIC                          -1009.232
# Time:                        18:34:59   BIC                           -930.560
# Sample:                             1   HQIC                          -977.483
#
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0020      0.001      1.606      0.108      -0.000       0.005
# ar.L1.D.Close     -0.0516      0.066     -0.778      0.437      -0.182       0.078
# ar.L2.D.Close      0.0559      0.066      0.843      0.400      -0.074       0.186
# ar.L3.D.Close     -0.0629      0.066     -0.951      0.341      -0.193       0.067
# ar.L4.D.Close      0.0153      0.066      0.231      0.817      -0.114       0.145
# ar.L5.D.Close     -0.0160      0.066     -0.242      0.808      -0.146       0.114
# ar.L6.D.Close      0.0665      0.066      1.004      0.315      -0.063       0.196
# ar.L7.D.Close      0.0584      0.067      0.870      0.384      -0.073       0.190
# ar.L8.D.Close     -0.0210      0.067     -0.314      0.753      -0.152       0.110
# ar.L9.D.Close     -0.0054      0.066     -0.081      0.935      -0.136       0.125
# ar.L10.D.Close    -0.0237      0.066     -0.358      0.721      -0.154       0.106
# ar.L11.D.Close    -0.0147      0.067     -0.221      0.825      -0.146       0.116
# ar.L12.D.Close    -0.0473      0.067     -0.708      0.479      -0.178       0.084
# ar.L13.D.Close    -0.0642      0.067     -0.961      0.336      -0.195       0.067
# ar.L14.D.Close    -0.0773      0.067     -1.152      0.249      -0.209       0.054
# ar.L15.D.Close     0.0199      0.068      0.293      0.769      -0.113       0.153
# ar.L16.D.Close    -0.0491      0.067     -0.728      0.467      -0.181       0.083
# ar.L17.D.Close     0.0058      0.068      0.085      0.932      -0.127       0.139
# ar.L18.D.Close     0.0522      0.068      0.770      0.442      -0.081       0.185
# ar.L19.D.Close    -0.1028      0.068     -1.518      0.129      -0.235       0.030
# ar.L20.D.Close    -0.0046      0.068     -0.068      0.946      -0.137       0.128
# ar.L21.D.Close     0.0189      0.067      0.281      0.779      -0.113       0.151
#                                     Roots
# ==============================================================================
#                    Real          Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# AR.1            -1.0626           -0.3244j            1.1110           -0.4528
# AR.2            -1.0626           +0.3244j            1.1110            0.4528
# AR.3            -1.1643           -0.0000j            1.1643           -0.5000
# AR.4            -0.8763           -0.6701j            1.1031           -0.3961
# AR.5            -0.8763           +0.6701j            1.1031            0.3961
# AR.6            -0.5697           -0.9251j            1.0865           -0.3379
# AR.7            -0.5697           +0.9251j            1.0865            0.3379
# AR.8            -0.2369           -1.0753j            1.1011           -0.2845
# AR.9            -0.2369           +1.0753j            1.1011            0.2845
# AR.10            0.1155           -1.1361j            1.1420           -0.2339
# AR.11            0.1155           +1.1361j            1.1420            0.2339
# AR.12            0.4655           -1.0061j            1.1085           -0.1810
# AR.13            0.4655           +1.0061j            1.1085            0.1810
# AR.14            0.7891           -0.8146j            1.1342           -0.1275
# AR.15            0.7891           +0.8146j            1.1342            0.1275
# AR.16            1.0812           -0.2271j            1.1048           -0.0330
# AR.17            1.0812           +0.2271j            1.1048            0.0330
# AR.18            1.0746           -0.6494j            1.2556           -0.0865
# AR.19            1.0746           +0.6494j            1.2556            0.0865
# AR.20           -2.3831           -0.0000j            2.3831           -0.5000
# AR.21            2.2308           -0.0000j            2.2308           -0.0000
# ------------------------------------------------------------------------------

# %%
# Forecast : 결과가 fc에 담깁니다. 
fc, se, conf = fitted_m.forecast(len(test_data), alpha=0.05)  # 95% conf

# Make as pandas series
fc_series = pd.Series(fc, index=test_data.index)   # 예측결과
lower_series = pd.Series(conf[:, 0], index=test_data.index)  # 예측결과의 하한 바운드
upper_series = pd.Series(conf[:, 1], index=test_data.index)  # 예측결과의 상한 바운드

# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, label='training')
plt.plot(test_data, c='b', label='actual price')
plt.plot(fc_series, c='r',label='predicted price')
plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.10)
plt.legend()
plt.show()

# %%
mse = mean_squared_error(np.exp(test_data), np.exp(fc))
print('MSE: ', mse)

mae = mean_absolute_error(np.exp(test_data), np.exp(fc))
print('MAE: ', mae)

rmse = math.sqrt(mean_squared_error(np.exp(test_data), np.exp(fc)))
print('RMSE: ', rmse)

mape = np.mean(np.abs(np.exp(fc) - np.exp(test_data))/np.abs(np.exp(test_data)))
print('MAPE: {:.2f}%'.format(mape*100))
# Out:
# MSE:  2877.978812050394
# MAE:  43.88878455537816
# RMSE:  53.64679684799824
# MAPE: 15.53%

# %% [markdown]
# ### 회고
# ---
# 다양한 종목들을 진행해봤습니다.\
# 원래는 노드에서 주어진 데이터만을 이용할 생각이었지만, 종목이 학습용 노드 미포함시 3가지가 안되고,\
# 또 종목이 주식종목 한정이라고 처음에 생각했기에, 추가적인 데이터를 받았습니다.
#
# 귀무가설을 기각하는 관례적인 값은 대개 0.05에서 0.01이라고 하는데, 이에 해당하는 값을 얻지는 못 했습니다.\
# 유일하게 값을 보인 온도 데이터도 사실 분산값등이 너무 커서 오류가 나므로 residual값을 넣은 것이라,\
# 안정적이라고 생각되진 않습니다.\
# (노드에선 residual을 이용하여 안정화하는 듯 하지만.. 모델에 직접 residual값을 훈련데이터로 넣는 것이 맞는 시도는 아닌 것 같습니다.)
# 비행기 모델을 통한 노드의 학습에서 그냥 로그화환 데이터를 넣을 뿐이기 때문입니다.\
#
# 모수값을 변경해가며 MAPE값을 낮춰본 결과,\
# 삼성주가, 비행기 승객 수, (residual을 이용했지만) 기간별 온도, HMM(현대상선)주가를 MAPE 15% 미만의 정확도로 예측할 수 있었습니다.
